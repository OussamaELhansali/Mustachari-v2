# %%
from llama_index.core import (
    VectorStoreIndex,
    ServiceContext,
    SimpleDirectoryReader,
)
def Docs_reader(link) :
    documents = SimpleDirectoryReader(link).load_data()
    return documents


documents = Docs_reader("C:\\Users\\XPS\\OneDrive - Ecole Centrale Casablanca\\Bureau\\Hackaton\\data1")
# documents = Docs_reader(r"C:\Users\XPS\OneDrive - Ecole Centrale Casablanca\Bureau\Hackaton\data")
print(documents)
# Out:
# [Document(id_='33796580-1a23-478a-acc2-7d1ad1220734', embedding=None, metadata={'page_label': '1', 'file_name': 'legislation-6294abb2180e1.pdf', 'file_path': 'C:\\Users\\XPS\\OneDrive - Ecole Centrale Casablanca\\Bureau\\Hackaton\\data1\\legislation-6294abb2180e1.pdf', 'file_type': 'application/pdf', 'file_size': 885077, 'creation_date': '2024-02-28', 'last_modified_date': '2024-02-28', 'last_accessed_date': '2024-02-28'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text='المملكة المغربية                                     وزارة العدل                                  مديرية التشريع \n \n  \n \n \n \n \n \n \n \n \n \nمدونة الأسرة \nصيغة محينة بتاريخ 52 يناير5102 \n  ', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', 
# ...

# %%
from llama_index.readers.file import PDFReader
def Docs_reader_pdf(link) :
    reader = PDFReader(return_full_document=True)
    documents = reader.load_data(link)
    return documents

documents_pdf = Docs_reader_pdf("C:\\Users\\XPS\\OneDrive - Ecole Centrale Casablanca\\Bureau\\Hackaton\\data1\\legislation-6294abb2180e1.pdf")

# %%
documents_pdf[0]
# Out:
# 'المملكة المغربية                                     وزارة العدل                                  مديرية التشريع \n \n  \n \n \n \n \n \n \n \n \n \nمدونة الأسرة \nصيغة محينة بتاريخ 52 يناير5102 \n  المملكة المغربية                                    وزارة العدل                                   مديرية التشريع \n \n- 2 -القانون رقم31.17 بمثابة مدونة الأسرة1 \nكما تم تعديله \n- القانون رقم 012201 الصادر بتنفيذه الظهير الشريف رقم020122 بتاريخ فاتحربيع \nالآخر 0341 (02 يناير2101)؛ الجريدة الرسمية عدد 1344 بتاريخ03 ربيع\nالآخر 0341 (21 يناير2101) ص321؛ \n- بالقانون رقم  10210 الصادر بتنفيذه الظهير الشريف رقم 02012014 بتاريخ4 \nشعبان0340  (01 يوليو2101 )؛ الجريدة الرسمية عدد 1010 بتاريخ04 شعبان\n0340  (21 يوليو2101) ص40412 \n \n  \n                                   \n1- الجريدة الرسمية عدد 1003 بتاريخ03 ذو الحجة0323 (1 فبراير2113)، ص3002 المملكة المغربية                                    وزارة العدل                                   مديرية التشريع \n \n- 4 -ظهير شريف رقم 0.14.55 صادر ف
# ...

# %%
import re
text= documents_pdf[0].text
pattern = r"\nالمادة \d+ \n"
matches = re.findall(pattern, text)

len(matches)
# Out:
# 360

# %%
print(documents_pdf[0].text)
# Out:
# المملكة المغربية                                     وزارة العدل                                  مديرية التشريع
#
#
#
#
#
#
#
#
#
#
#
# مدونة الأسرة
# صيغة محينة بتاريخ 52 يناير5102
#   المملكة المغربية                                    وزارة العدل                                   مديرية التشريع
#
# - 2 -القانون رقم31.17 بمثابة مدونة الأسرة1
# كما تم تعديله
# - القانون رقم 012201 الصادر بتنفيذه الظهير الشريف رقم020122 بتاريخ فاتحربيع
# الآخر 0341 (02 يناير2101)؛ الجريدة الرسمية عدد 1344 بتاريخ03 ربيع
# الآخر 0341 (21 يناير2101) ص321؛
# - بالقانون رقم  10210 الصادر بتنفيذه الظهير الشريف رقم 02012014 بتاريخ4
# شعبان0340  (01 يوليو2101 )؛ الجريدة الرسمية عدد 1010 بتاريخ04 شعبان
# 0340  (21 يوليو2101) ص40412
#
#
#
# 1- الجريدة الرسمية عدد 1003 بتاريخ03 ذو الحجة0323 (1 فبراير2113)، ص3002 المملكة المغربية                                    وزارة العدل                                   مديرية التشريع
#
# - 4 -ظهير شريف رقم 0.14.55 صادر في05 من ذي الحجة
# ...

# %%
documents[0].id_
# Out:
# 'c1cf90dc-112f-49de-9d3a-2071d7ec5047'

# %%
import re
text= documents_pdf[0].text
pattern = r"\nالمادة \d+ \n"
matches = re.findall(pattern, text)

len(matches)
# Out:
# 360

# %%
matches = re.findall(pattern, text)

for match in matches:
    print(f"Found match: {match}")
# Out:
# Found match:
# المادة 0
#
# Found match:
# المادة 5
#
# Found match:
# المادة 7
#
# Found match:
# المادة 4
#
# Found match:
# المادة 2
#
# Found match:
# المادة 2
#
# Found match:
# المادة 3
#
# Found match:
# المادة 8
#
# Found match:
# المادة 9
#
# Found match:
# المادة 01
#
# Found match:
# المادة 00
#
# Found match:
# المادة 07
#
# Found match:
# المادة 04
#
# Found match:
# المادة 02
#
# Found match:
# المادة 02
#
# Found match:
# المادة 08
#
# Found match:
# المادة 09
#
# Found match:
# المادة 51
#
# Found match:
# المادة 50
#
# Found match:
# المادة 55
#
# Found match:
# المادة 57
#
# Found match:
# المادة 54
#
# Found match:
# المادة 52
#
# Found match:
# المادة 52
#
# Found match:
# المادة 53
#
# Found match:
# المادة 58
#
# Found match:
# المادة 59
#
# Found match:
# المادة 71
#
# Found match:
# المادة 70
#
# Found match:
# المادة 75
#
# Found match:
# المادة 77
#
# Found match:
# المادة 74
#
# Found match:
# المادة 72
#
# Found match:
# المادة 72
#
# Found match:
# ...

# %%
documents[0].text="aaugugbuaaabhbjbkhb kn kjn n ihjnojnunib bbbcccc"

# %%
print(documents[0])
# Out:
# Doc ID: 33796580-1a23-478a-acc2-7d1ad1220734
# Text: aaugugbuaaabhbjbkhb kn kjn n ihjnojnunib bbbcccc

# %%
from llama_index.core.node_parser import SentenceSplitter
import tiktoken
splitter = SentenceSplitter(
    chunk_size=48,
    chunk_overlap=0
    # separator=" ",
    # paragraph_separator="ab",
    # secondary_chunking_regex="ab",  # Your regex goes here
    # tokenizer=tiktoken.encoding_for_model("gpt-3.5-turbo").encode,
)
nodes = splitter.get_nodes_from_documents([documents[0]])
len(nodes)
# Out:
# Metadata length (47) is close to chunk size (48). Resulting chunks are less than 50 tokens. Consider increasing the chunk size or decreasing the size of your metadata to avoid this.
# 42

# %%
nodes[15].text
# Out:
# 'b'

# %%
text_splitter = SentenceSplitter(
    separator=" ",
    chunk_size=1024,
    chunk_overlap=20,
    paragraph_separator="\n\n\n",
    secondary_chunking_regex=r"\nالمادة \d+ \n",  # Your regex goes here
    tokenizer=tiktoken.encoding_for_model("gpt-3.5-turbo").encode,
)
nodes = splitter.get_nodes_from_documents([documents[0]])
len(nodes)
# Out:
# 19

# %%
nodes[0].text
# Out:
# 'المملكة المغربية                                     وزارة العدل                                  مديرية التشريع \n \n  \n \n \n \n \n \n \n \n \n \nمدونة الأسرة \nصيغة محينة بتاريخ 52 يناير5102 \n   المملكة المغربية                                    وزارة العدل                                   مديرية التشريع \n \n- 2 -القانون رقم31.17 بمثابة مدونة الأسرة1 \nكما تم تعديله \n- القانون رقم 012201 الصادر بتنفيذه الظهير الشريف رقم020122 بتاريخ فاتحربيع \nالآخر 0341 (02 يناير2101)؛ الجريدة الرسمية عدد 1344 بتاريخ03 ربيع\nالآخر 0341 (21 يناير2101) ص321؛ \n- بالقانون رقم  10210 الصادر بتنفيذه الظهير الشريف رقم 02012014 بتاريخ4 \nشعبان0340  (01 يوليو2101 )؛ الجريدة الرسمية عدد 1010 بتاريخ04 شعبان\n0340  (21 يوليو2101) ص40412 \n \n  \n                                   \n1- الجريدة الرسمية عدد 1003 بتاريخ03 ذو الحجة0323 (1 فبراير2113)، ص3002  المملكة المغربية                                    وزارة العدل                                   مديرية التشريع \n \n- 4 -ظهير شريف رقم 0.14.55 صادر
# ...

# %%
matches = re.findall(pattern, nodes[0].text)
for match in matches:
    print(f"Found match: {match}")

# %%
nodes[0].text
# Out:
# 'المملكة المغربية                                     وزارة العدل                                  مديرية التشريع \n \n  \n \n \n \n \n \n \n \n \n \nمدونة الأسرة \nصيغة محينة بتاريخ 52 يناير5102 \n   المملكة المغربية                                    وزارة العدل                                   مديرية التشريع \n \n- 2 -القانون رقم31.17 بمثابة مدونة الأسرة1 \nكما تم تعديله \n- القانون رقم 012201 الصادر بتنفيذه الظهير الشريف رقم020122 بتاريخ فاتحربيع \nالآخر 0341 (02 يناير2101)؛ الجريدة الرسمية عدد 1344 بتاريخ03 ربيع\nالآخر 0341 (21 يناير2101) ص321؛ \n- بالقانون رقم  10210 الصادر بتنفيذه الظهير الشريف رقم 02012014 بتاريخ4 \nشعبان0340  (01 يوليو2101 )؛ الجريدة الرسمية عدد 1010 بتاريخ04 شعبان\n0340  (21 يوليو2101) ص40412 \n \n  \n                                   \n1- الجريدة الرسمية عدد 1003 بتاريخ03 ذو الحجة0323 (1 فبراير2113)، ص3002  المملكة المغربية                                    وزارة العدل                                   مديرية التشريع \n \n- 4 -ظهير شريف رقم 0.14.55 صادر
# ...

# %%
import re
# Out:
# [TextNode(id_='4972c2c8-4dd1-4608-bc11-c8de982324e8', embedding=None, metadata={'page_label': '1', 'file_name': 'legislation-6294abb2180e1.pdf', 'file_path': 'C:\\Users\\XPS\\OneDrive - Ecole Centrale Casablanca\\Bureau\\Hackaton\\data1\\legislation-6294abb2180e1.pdf', 'file_type': 'application/pdf', 'file_size': 885077, 'creation_date': '2024-02-28', 'last_modified_date': '2024-02-28', 'last_accessed_date': '2024-02-28'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='d262f86d-8f26-43e9-820e-989b4ac5398a', node_type=<ObjectType.DOCUMENT: '4'>, metadata={'page_label': '1', 'file_name': 'legislation-6294abb2180e1.pdf', 'file_path': 'C:\\Users\\XPS\\OneDrive - Ecole Centrale Casablanca\\Bureau\\Hackaton\\d
# ...

# %%
pattern = r':\s*\\nالمادة\s+7\s*\\n'
matches = re.findall(pattern, nodes[0].text)

# %%
for i, node in enumerate(nodes[:2]):
    print(f"Node {i+1} content: {node.get_content()}")
# Out:
# Node 1 content: المملكة المغربية                                     وزارة العدل                                  مديرية التشريع
#
#
#
#
#
#
#
#
#
#
#
# مدونة الأسرة
# صيغة محينة بتاريخ 52 يناير5102
# Node 2 content: المملكة المغربية                                    وزارة العدل                                   مديرية التشريع
#
# - 2 -القانون رقم31.17 بمثابة مدونة الأسرة1
# كما تم تعديله
# - القانون رقم 012201 الصادر بتنفيذه الظهير الشريف رقم020122 بتاريخ فاتحربيع
# الآخر 0341 (02 يناير2101)؛ الجريدة الرسمية عدد 1344 بتاريخ03 ربيع
# الآخر 0341 (21 يناير2101) ص321؛
# - بالقانون رقم  10210 الصادر بتنفيذه الظهير الشريف رقم 02012014 بتاريخ4
# شعبان0340  (01 يوليو2101 )؛ الجريدة الرسمية عدد 1010 بتاريخ04 شعبان
# 0340  (21 يوليو2101) ص40412
#
#
#
# 1- الجريدة الرسمية عدد 1003 بتاريخ03 ذو الحجة0323 (1 فبراير2113)، ص3002

# %%
with open("aze.txt", "w") as f:
    for d in documents:
        f.write(d.text)

# %%
from llama_index.core import VectorStoreIndex, StorageContext
from llama_index.embeddings.gemini import GeminiEmbedding
from llama_index.llms.gemini import Gemini
from llama_index.vector_stores.qdrant import QdrantVectorStore
from llama_index.core import Settings
from llama_index.core import StorageContext
from llama_index.core.node_parser import SentenceSplitter
from llama_index.embeddings.openai import OpenAIEmbedding
import os
import qdrant_client

GOOGLE_API_KEY = "AIzaSyCHmmFgBimvvjn_ahULahxEnl76a_pXp8s"  # add your GOOGLE API key here

os.environ["GOOGLE_API_KEY"] = GOOGLE_API_KEY

def load_embedding_model():
    return OpenAIEmbedding()
Settings.embed_model = load_embedding_model()
Settings.llm = Gemini(api_key=GOOGLE_API_KEY)

client = qdrant_client.QdrantClient(path="qdrant_gemini_3")

vector_store = QdrantVectorStore(client=client, collection_name="collection")

storage_context = StorageContext.from_defaults(vector_store=vector_store)

splitter = SentenceSplitter(
    chunk_size=1024,
    chunk_overlap=20,
)
nodes = splitter.get_nodes_from_documents(documents)
index = VectorStoreIndex(
    nodes=nodes ,
    storage_context=storage_context,
)
query_engine = index.as_query_engine(
    similarity_top_k=1,
)

# %% [markdown]
# ---------------------------------
# --------------------------------

# %% [markdown]
# ## Preparing the Data with Metadata

# %%
with open("loi.txt",'r') as f:
    full_text = f.read()

print(full_text)

# %%
from preprocess import preprocessing
preprocessing("loi.txt")
# Out:
# [{'text': 'مديرية التشريع\nيطلق على هذا القانون اسم مدونة الأسرة، ويشار إليها بعده باسم المدونة.\nتسري أحكام هذه المدونة على:',
#   'metadata': 'المادة رقم 1 '},
#  {'text': '1 - جميع المغاربة ولو كانوا حاملين لجنسية أخرى؛\n2 - اللاجئين بمن فيهم عديمو الجنسية، طبقا لاتفاقية جنيف المؤرخة بـ 28 يوليوز\nلسنة 1951 المتعلقة بوضعية اللاجئين؛\n3 - العلاقات التى يكون فيها أحد الطرفين مغربيا؛\n4 - العلاقات التي تكون بين مغربيين أحدهما مسلم.\nأما اليهود المغاربة فتسري عليهم قواعد الأحوال الشخصية العبرية المغربية.',
#   'metadata': 'المادة رقم 2 '},
#  {'text': 'تعتبر النيابة العامة طرفا أصليا في جميع القضايا الرامية إلى تطبيق أحكام هذه\nالمدونة.\nالكتاب الأول: الزواج\nالقسم الأول: الخطبة والزواج',
#   'metadata': 'المادة رقم 3 '},
#  {'text': 'الزواج ميثاق تراض وترابط شرعي بين رجل وامرأة على وجه الدوام، غايته\nالإحصان والعفاف وإنشاء أسرة مستقرة، برعاية الزوجين طبقا لأحكام هذه المدونة.\n- 10 -\nالمملكة المغربية\nوزارة العدل\nمديرية التشريع\nالباب الأول: الخطبة',
# ...

# %%
with open("loi.txt",'r') as f:
    full_text = f.read()

print(full_text)

# %%
import re
full_text.replace("المملكة المغربية\nوزارة العدل\nمديرية التشريع\n","")
pattern = r"\nالمادة \d+\n"
matches = re.findall(pattern, full_text)

for match in matches:
    print(f"Found match: {match}")
print(len(matches))

# %%
matches = re.finditer(pattern , full_text)
chapter_contents = []
start_index = 0

for match in matches:
    end_index = match.start()
    chapter_content = full_text[start_index:end_index].strip()
    chapter_contents.append(chapter_content)
    
    start_index = match.end()

last_chapter_content = full_text[start_index:].strip()
chapter_contents.append(last_chapter_content)

data = []
for i, content in enumerate(chapter_contents, start=1):
    d={"text":"","metadata":""}
    metadata =f"المادة رقم {i-1} "
    text = content
    d["text"] = text
    d["metadata"] = metadata
    data.append(d)

data = data[1:]

# %%
data[0]
# Out:
# 398

# %%
print(data[5]['text'])
# Out:
# يعتبر الطرفان في فترة خطبة إلى حين الإشهاد على عقد الزواج، ولكل من الطرفين
# حق العدول عنها.

# %%
print(data[0]['text'])
# Out:
# مديرية التشريع
# يطلق على هذا القانون اسم مدونة الأسرة، ويشار إليها بعده باسم المدونة.
# تسري أحكام هذه المدونة على:

# %%
dico[data[4]['text']]
# Out:
# 'المادة رقم 5 '

# %%
import json



# Specify the file path
file_path = "data.json"

# Save the dictionary to a JSON file
with open(file_path, 'w') as json_file:
    json.dump(dico, json_file)

print(f"The dictionary has been saved to {file_path}")
# Out:
# The dictionary has been saved to data.json

# %%
with open(file_path, 'r') as json_file:
    loaded_dict = json.load(json_file)
    print(loaded_dict)
# Out:
# {'مديرية التشريع\nيطلق على هذا القانون اسم مدونة الأسرة، ويشار إليها بعده باسم المدونة.\nتسري أحكام هذه المدونة على:': 'المادة رقم 1 ', '1 - جميع المغاربة ولو كانوا حاملين لجنسية أخرى؛\n2 - اللاجئين بمن فيهم عديمو الجنسية، طبقا لاتفاقية جنيف المؤرخة بـ 28 يوليوز\nلسنة 1951 المتعلقة بوضعية اللاجئين؛\n3 - العلاقات التى يكون فيها أحد الطرفين مغربيا؛\n4 - العلاقات التي تكون بين مغربيين أحدهما مسلم.\nأما اليهود المغاربة فتسري عليهم قواعد الأحوال الشخصية العبرية المغربية.': 'المادة رقم 2 ', 'تعتبر النيابة العامة طرفا أصليا في جميع القضايا الرامية إلى تطبيق أحكام هذه\nالمدونة.\nالكتاب الأول: الزواج\nالقسم الأول: الخطبة والزواج': 'المادة رقم 3 ', 'الزواج ميثاق تراض وترابط شرعي بين رجل وامرأة على وجه الدوام، غايته\nالإحصان والعفاف وإنشاء أسرة مستقرة، برعاية الزوجين طبقا لأحكام هذه المدونة.\n- 10 -\nالمملكة المغربية\nوزارة العدل\nمديرية التشريع\nالباب الأول: الخطبة': 'المادة رقم 4 ', 'الخطبة تواعد رجل وامرأة على الزواج.\nتتحقق الخطبة بتعبير طرفيها بأي وسيلة متعارف عليها تفيد التواعد على الزواج
# ...

# %%
dico = {i['text']:i["metadata"] for i in data}
dico
# Out:
# {'مديرية التشريع\nيطلق على هذا القانون اسم مدونة الأسرة، ويشار إليها بعده باسم المدونة.\nتسري أحكام هذه المدونة على:': 'المادة رقم 1 ',
#  '1 - جميع المغاربة ولو كانوا حاملين لجنسية أخرى؛\n2 - اللاجئين بمن فيهم عديمو الجنسية، طبقا لاتفاقية جنيف المؤرخة بـ 28 يوليوز\nلسنة 1951 المتعلقة بوضعية اللاجئين؛\n3 - العلاقات التى يكون فيها أحد الطرفين مغربيا؛\n4 - العلاقات التي تكون بين مغربيين أحدهما مسلم.\nأما اليهود المغاربة فتسري عليهم قواعد الأحوال الشخصية العبرية المغربية.': 'المادة رقم 2 ',
#  'تعتبر النيابة العامة طرفا أصليا في جميع القضايا الرامية إلى تطبيق أحكام هذه\nالمدونة.\nالكتاب الأول: الزواج\nالقسم الأول: الخطبة والزواج': 'المادة رقم 3 ',
#  'الزواج ميثاق تراض وترابط شرعي بين رجل وامرأة على وجه الدوام، غايته\nالإحصان والعفاف وإنشاء أسرة مستقرة، برعاية الزوجين طبقا لأحكام هذه المدونة.\n- 10 -\nالمملكة المغربية\nوزارة العدل\nمديرية التشريع\nالباب الأول: الخطبة': 'المادة رقم 4 ',
# ...

# %%
from llama_index.core import VectorStoreIndex, Document
from llama_index.core.vector_stores import MetadataFilters, ExactMatchFilter
documents = [Document(text=d["text"], metadata={"المادة": d["metadata"]}) for d in data]
len(documents)
# Out:
# 398

# %%
import os
from llama_index.embeddings.openai import OpenAIEmbedding
from llama_index.llms.openai import OpenAI
OPENAI_API_KEY = "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"
os.environ["OPENAI_API_KEY"] = OPENAI_API_KEY

embed_model = OpenAIEmbedding()
service_context = ServiceContext.from_defaults(
    llm=OpenAI(api_key=OPENAI_API_KEY), embed_model=embed_model
)
vector_index = VectorStoreIndex.from_documents(
    documents, service_context=service_context
)
index = vector_index
# Out:
# C:\Users\XPS\AppData\Local\Temp\ipykernel_29892\2422948997.py:8: DeprecationWarning: Call to deprecated class method from_defaults. (ServiceContext is deprecated, please use `llama_index.settings.Settings` instead.) -- Deprecated since version 0.10.0.
#   service_context = ServiceContext.from_defaults(

# %%
documents[1]
# Out:
# Document(id_='86a4d3a5-b1cc-46c2-8a0a-eb3ab8bf69d5', embedding=None, metadata={'المادة': 'المادة رقم 2 '}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, text='1 - جميع المغاربة ولو كانوا حاملين لجنسية أخرى؛\n2 - اللاجئين بمن فيهم عديمو الجنسية، طبقا لاتفاقية جنيف المؤرخة بـ 28 يوليوز\nلسنة 1951 المتعلقة بوضعية اللاجئين؛\n3 - العلاقات التى يكون فيها أحد الطرفين مغربيا؛\n4 - العلاقات التي تكون بين مغربيين أحدهما مسلم.\nأما اليهود المغاربة فتسري عليهم قواعد الأحوال الشخصية العبرية المغربية.', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n')

# %%
documents
# Out:
# [Document(id_='f55faf33-caec-4a94-a106-ccad58997527', embedding=None, metadata={'المادة': 'المادة رقم 1 '}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, text='مديرية التشريع\nيطلق على هذا القانون اسم مدونة الأسرة، ويشار إليها بعده باسم المدونة.\nتسري أحكام هذه المدونة على:', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
# ...

# %%
query_engine2 = index.as_query_engine(service_context=service_context,similarity_top_k=3)

# %%
query = "في حالة ادعاء المعتدة الريبة في الحمل ما الاجراء الدي يجب اتخاده"
response = query_engine2.query(query)
print(response)
# Out:
# يجب رفع الأمر إلى المحكمة التي تستعين بذوي الاختصاص من الخبراء للتأكد من وجود الحمل وفترة نشوئه لتقرر استمرار العدة أو انتهاءها.

# %%
query = "ما هي اسباب الحجر؟"
response = query_engine2.query(query)
print(response)

# %%
nodes = query_engine2.retrieve(query)
# Now, 'nodes' is a list of Node objects. You can access the metadata of each node like this:
for node in nodes:
    print(node.metadata)
# Out:
# {'المادة': 'المادة رقم 134 '}
# {'المادة': 'المادة رقم 388 '}
# {'المادة': 'المادة رقم 385 '}

# %%
prompt = f"answer in arabic this question:{query} and add at the end the following metadata: according to {query_engine2.retrieve(query)[0].metadata}"
response = query_engine2.query(prompt)
print(response)

# %% [markdown]
# ## BAAI model

# %%
from llama_index.core import VectorStoreIndex, StorageContext
from llama_index.embeddings.gemini import GeminiEmbedding
from llama_index.llms.gemini import Gemini
import google.generativeai as genai 
from llama_index.embeddings.huggingface import HuggingFaceEmbedding

# %%
GOOGLE_API_KEY = "AIzaSyCjdp6YWSIupVTbVrt653GAXcYlsFqWUDA"  # add your GOOGLE API key here
os.environ["GOOGLE_API_KEY"] = GOOGLE_API_KEY
embed_model = HuggingFaceEmbedding(
    model_name="BAAI/bge-small-en-v1.5"
)
service_context_ab = ServiceContext.from_defaults(
    llm=Gemini(api_key=GOOGLE_API_KEY), embed_model=embed_model
)
vector_index_ab = VectorStoreIndex.from_documents(
    documents, service_context=service_context_ab
)
index_ab = vector_index_ab 
index.storage_context.persist(persist_dir=r"C:\Users\XPS\OneDrive - Ecole Centrale Casablanca\Bureau\Hackaton\Meta_Data_Extraction")
engine_ab = index_ab.as_query_engine(service_context=service_context_ab,similarity_top_k=3)
# Out:
# C:\Users\XPS\AppData\Local\Temp\ipykernel_29892\2160311999.py:6: DeprecationWarning: Call to deprecated class method from_defaults. (ServiceContext is deprecated, please use `llama_index.settings.Settings` instead.) -- Deprecated since version 0.10.0.
#   service_context_ab = ServiceContext.from_defaults(

# %%
prompt = f"answer in arabic this question:{query} and add at the end the following metadata: according to {query_engine2.retrieve(query)[0].metadata}"
response = engine_ab.query(prompt)
print(response)
# Out:
# في حالة ادعاء المعتدة الريبة في الحمل، وحصول المنازعة في ذلك، يرفع الأمر إلى المحكمة التي تستعين بذوي الاختصاص من الخبراء للتأكد من وجود الحمل وفترة نشوئه لِتقرر استمرار العدة أو انتهاءها. according to {'المادة': 'المادة رقم 134 '}

# %%
query = "ما هي أسباب الحجر"
prompt = f"answer in arabic this question:{query} and add at the end the following metadata: according to {query_engine2.retrieve(query)[0].metadata}"
response = engine_ab.query(prompt)
print(response)
# Out:
# أسباب الحجر نوعان: الأول ينقص الأهلية والثاني يعدمها. according to {'المادة': 'المادة رقم 211 '}

# %%
from llama_index.core import load_index_from_storage
st = StorageContext.from_defaults(persist_dir=r"C:\Users\XPS\OneDrive - Ecole Centrale Casablanca\Bureau\Hackaton\Meta_Data_Extraction")
ide = load_index_from_storage(st)
eg = ide.as_query_engine(service_context=service_context_ab,similarity_top_k=3)

# %%
query_1 = "ما هي شروط ولاية الأم لأولادها؟"
prompt = f"answer in arabic this question:{query_1} and add at the end the following metadata: according to {query_engine2.retrieve(query_1)[0].metadata}"
response = eg.query(prompt)
print(response)
# Out:
# تكون ولاية الأم على أولادها بحكم الشرع، ما لم يجرد من ولايتها بحكم قضائي، ولها أن تقوم بالمصالح المستعجلة لأولادها في حالة حصول مانع للأب. وفقا لـ {'المادة': 'المادة رقم 235 '}

# %%
nodes = query_engine2.retrieve(query_1)
for node in nodes:
    print(node.metadata)
# Out:
# {'المادة': 'المادة رقم 235 '}
# {'المادة': 'المادة رقم 196 '}
# {'المادة': 'المادة رقم 197 '}

# %% [markdown]
# ### Model 2 miniLM

# %%
GOOGLE_API_KEY = "AIzaSyCjdp6YWSIupVTbVrt653GAXcYlsFqWUDA"  # add your GOOGLE API key here
os.environ["GOOGLE_API_KEY"] = GOOGLE_API_KEY
embed_model_2 = HuggingFaceEmbedding(
    model_name="sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2"
)
service_context_2 = ServiceContext.from_defaults(
    llm=Gemini(api_key=GOOGLE_API_KEY), embed_model=embed_model_2
)
vector_index_2 = VectorStoreIndex.from_documents(
    documents, service_context=service_context_2
)
index_2 = vector_index_2
index_2.storage_context.persist(persist_dir=r"C:\Users\XPS\OneDrive - Ecole Centrale Casablanca\Bureau\Hackaton\Meta_Data_Extraction\model_2")
engine_2 = index_ab.as_query_engine(service_context=service_context_2,similarity_top_k=3)
# Out:
# C:\Users\XPS\AppData\Local\Temp\ipykernel_29892\466619023.py:6: DeprecationWarning: Call to deprecated class method from_defaults. (ServiceContext is deprecated, please use `llama_index.settings.Settings` instead.) -- Deprecated since version 0.10.0.
#   service_context_2 = ServiceContext.from_defaults(

# %%
query_1 = "ما هي شروط ولاية الأم لأولادها؟"
prompt = f"answer in arabic this question:{query_1} and add at the end the following metadata: according to {query_engine2.retrieve(query_1)[0].metadata}"
response = engine_2.query(prompt)
print(response)
# Out:
# حصول مانع للأب.
# {'المادة': 'المادة رقم 235 '}
